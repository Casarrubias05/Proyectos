# %%
import pandas as pd

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy as sc
#%matplotlib widget

import itertools as iter
from scipy import constants

ep = constants.epsilon_0
c = constants.c

# %% [markdown]
# # Álgebra Lineal Simbólíca

# %%
from sympy import I
alpha, beta, phi_x, phi_y, EF, E_x, E_y, s = sy.symbols('alpha, beta, phi_x, phi_y, E, E_x, E_y s', real=True)

# %%
theta, epsilon_x, Delta = sy.symbols('theta, epsilon_x, Delta', real=True)
#Transformaciones
rotation = sy.Matrix([
	[sy.sin(alpha), sy.cos(alpha)],
	[-sy.cos(alpha), sy.sin(alpha)]
])

retarder = sy.diag(1, sy.exp(I*Delta))

polarizer = sy.Matrix([
	[(sy.cos(theta-alpha))**2, sy.sin(theta-alpha)*sy.cos(theta-alpha)],
	[sy.sin(theta-alpha)*sy.cos(theta-alpha), (sy.sin(theta-alpha))**2]
])
retarder
# Out:
# Matrix([
# [1,            0],
# [0, exp(I*Delta)]])

# %%
E = sy.Matrix([sy.cos(beta), sy.sin(beta)])
E1_ = sy.simplify(
	(sy.exp(I*s)*polarizer*retarder*(rotation**(-1))*E).subs([(Delta, sy.pi)]))
display(sy.simplify(rotation*E), E1_)
# Out:
# Matrix([
# [ sin(alpha + beta)],
# [-cos(alpha + beta)]])
# Matrix([
# [(-cos(-3*alpha + beta + theta) + cos(-alpha + beta + theta))*exp(I*s)*cos(alpha - theta)/(2*sin(alpha))],
# [ (cos(-3*alpha + beta + theta) - cos(-alpha + beta + theta))*exp(I*s)*sin(alpha - theta)/(2*sin(alpha))]])

# %%
E2 = sy.simplify(sy.re(E1_[0])**2 + sy.re(E1_[1])**2)
E2#.subs([(alpha, sy.pi/2), (beta, angulo_max1)])
# Out:
# (cos(-3*alpha + beta + theta) - cos(-alpha + beta + theta))**2*cos(s)**2/(4*sin(alpha)**2)

# %%
E2_1 = (E2.expand()).subs([((sy.cos(s))**2, 1/2), (alpha, sy.pi/6), (beta, angulo_max2)])
E2_1 = (E2_1.factor())
E2_1
# Out:
# 0.5*(1.0*sin(theta + 1.22173047639603) - 1.0*sin(theta + pi/3 + 1.22173047639603))**2

# %%
Malus_Ley_MOD = sy.lambdify(theta, E2_1, 'numpy')

# %%
E1_2 = sy.simplify(
	(sy.exp(I*s)*polarizer*retarder*(rotation**(-1))*E).subs([(Delta, sy.pi/2)]))
display(sy.simplify(rotation*E), E1_2)
# Out:
# Matrix([
# [ sin(alpha + beta)],
# [-cos(alpha + beta)]])
# Matrix([
# [  (1 - I)*((1 + I)*cos(beta) - (1 + I)*cos(2*alpha - beta) - I*cos(beta - 2*theta) - cos(-4*alpha + beta + 2*theta) + cos(-2*alpha + beta + 2*theta) + I*cos(2*alpha + beta - 2*theta))*exp(I*s)/(8*sin(alpha))],
# [(1 - I)*((-1 + I)*sin(beta) + (-1 + I)*sin(2*alpha - beta) + I*sin(beta - 2*theta) - sin(-4*alpha + beta + 2*theta) + sin(-2*alpha + beta + 2*theta) - I*sin(2*alpha + beta - 2*theta))*exp(I*s)/(8*sin(alpha))]])

# %%
E3 = sy.simplify(sy.re(E1_2[0])**2 + sy.re(E1_2[1])**2)
E3#.subs([(alpha, sy.pi/2), (beta, angulo_max1)])
# Out:
# (((sin(beta - 2*theta) - sin(-4*alpha + beta + 2*theta) + sin(-2*alpha + beta + 2*theta) - sin(2*alpha + beta - 2*theta))*cos(s) - (2*sin(beta) + 2*sin(2*alpha - beta) + sin(beta - 2*theta) + sin(-4*alpha + beta + 2*theta) - sin(-2*alpha + beta + 2*theta) - sin(2*alpha + beta - 2*theta))*sin(s))**2 + ((cos(beta - 2*theta) - cos(-4*alpha + beta + 2*theta) + cos(-2*alpha + beta + 2*theta) - cos(2*alpha + beta - 2*theta))*sin(s) + (2*cos(beta) - 2*cos(2*alpha - beta) - cos(beta - 2*theta) - cos(-4*alpha + beta + 2*theta) + cos(-2*alpha + beta + 2*theta) + cos(2*alpha + beta - 2*theta))*cos(s))**2)/(64*sin(alpha)**2)

# %%
E2_2 = (E3.expand()).subs(
	[
		((sy.cos(s))**2, 1/2), ((sy.sin(s))**2, 1/2), (alpha, sy.pi/4), (beta, angulo_max3),
		(sy.sin(s), 0), (sy.cos(s), 0)
	]
)
E2_2 = (E2_2.factor())
E2_2
# Out:
# 0.125*(0.5*sin(2*theta - 1.39626340159546)**2 - 0.984807753012208*sin(2*theta - 1.39626340159546) + 0.5*sin(2*theta + 1.39626340159546)**2 - 0.984807753012208*sin(2*theta + 1.39626340159546) + 0.5*cos(2*theta - 1.39626340159546)**2 - 0.17364817766693*cos(2*theta - 1.39626340159546) + 0.5*cos(2*theta + 1.39626340159546)**2 + 0.17364817766693*cos(2*theta + 1.39626340159546) + 1.0)

# %%
Malus_Ley_MOD1 = sy.lambdify(theta, E2_2, 'numpy')

# %%
def Malus_Law_Retarder(polarization, retarder_angle, retarder_phase):
	from sympy import I
	alpha, beta, theta, s = sy.symbols('alpha, beta, theta, s', real=True)
	#alpha: ángulo del eje rápido del retardador respecto a la horizontal.
	#beta: ángulo del eje de transmisión del polarizador respecto a la horizontal.
	#theta: polarización lineal del campo eléctrico.
	#s: kz - wt, introducido para hacer promedios como <cos^2(s)> = 1/2.
	
	linear_E = sy.Matrix([sy.cos(theta), sy.sin(theta)])
	
	rotation = sy.Matrix([
		[sy.sin(alpha), sy.cos(alpha)],
		[-sy.cos(alpha), sy.sin(alpha)]
	])
	
	retarder = sy.diag(1, sy.exp(I*retarder_phase))
	
	polarizer = sy.Matrix([
		[(sy.cos(beta-alpha))**2, sy.sin(beta-alpha)*sy.cos(beta-alpha)],
		[sy.sin(beta-alpha)*sy.cos(beta-alpha), (sy.sin(beta-alpha))**2]
	])

	transformed_E = sy.simplify(
		(sy.exp(I*s)*polarizer*retarder*(rotation**(-1))*linear_E)
	)

	norm_real_E = (sy.re(transformed_E[0])**2 + sy.re(transformed_E[1])**2)
	average_norm_E = (norm_real_E.expand()).subs([((sy.cos(s))**2, 1/2), ((sy.sin(s))**2, 1/2), ((sy.sin(s)), 0)])

	returned_E = sy.simplify(average_norm_E)
	display(returned_E)
	return returned_E.subs([(alpha, retarder_angle), (theta, polarization)])

# %%
Malus_Law_Retarder(angulo_max2, sy.pi/3, sy.pi)
# Out:
# 0.125*(cos(-3*alpha + beta + theta) - cos(-alpha + beta + theta))**2/sin(alpha)**2
# 0.166666666666667*(-sin(beta + pi/6 + 1.22173047639603) - cos(beta + 1.22173047639603))**2

# %%
Malus_Law_Retarder_1 = sy.lambdify(beta, Malus_Law_Retarder(angulo_max2, sy.pi/6, sy.pi), 'numpy')

# %% [markdown]
# # Gráficas

# %%
datos_polarizacion_PATH = '/Users/GLaDOS_1/Documents/GitHub/Proyectos/Lab Optica/Practica 7/Datos.xlsx'
with pd.ExcelFile(datos_polarizacion_PATH) as tabla_datos:
	#Extrae los datos del archivo de Excel a un diccionario de dataframes, eliminando la columna de 'líneas'
	#y convirtiendo los ángulos de grados a radianes.
	mediciones = tabla_datos.parse(sheet_name=[0, 1, 2, 3], usecols=[1, 2, 3], converters={'Ángulo': np.radians})

# %%
sorted_mediciones = mediciones[0].sort_values(by='Intensidad Min', ascending=False)
second_max = sorted_mediciones
second_max['Ángulo'].iloc[2]
# Out:
# np.float64(2.792526803190927)

# %%
second_max
# Out:
# np.float64(1.269)

# %%
angulos = np.linspace(0, mediciones[0]['Ángulo'].max(), 100)
Malus_Ley = lambda intensidades, angulo: intensidades.max() * np.cos(angulo)**2

fig, axs = plt.subplots(figsize=(10,8), nrows=2, ncols=2, sharex=True)
captions = ['({})'.format(label) for label in ['a', 'b', 'c', 'd']]
#print(captions)

figure_positions = iter.product(range(2), repeat=2)
for index, position in enumerate(figure_positions):
	figure = axs[position]
	figure.set(xlabel='Ángulo [rad]', ylabel='Intensidad [mW]')
	#figure.grid()

	
	plotted_data = mediciones[index]
	intensidad_max_2 = plotted_data['Intensidad Max'].nlargest(2).iloc[1]
	fase = plotted_data[plotted_data['Intensidad Max'] == intensidad_max_2].iloc[0, 0]
	x = (plotted_data['Ángulo'])
	average_y = (plotted_data['Intensidad Min'] + plotted_data['Intensidad Max'])/2
	#y_error = plotted_data['Intensidad Max'] - average_y
	
	figure.scatter(x, average_y, color='k', label=captions[index])
	figure.plot(angulos, Malus_Ley(average_y, angulos - fase))
	figure.legend()
	#figure.plot(x, Malus_Ley(average_y, x))

plt.savefig('Intensidades.pdf', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(9,7))
ax.set(xlabel='Ángulo [rad]', ylabel='Intensidad [mW]')
ax.grid()

plots = []

figure_positions = iter.product(range(2), repeat=2)
for index, position in enumerate(figure_positions):
	figure = ax

	plotted_data = mediciones[index]
	intensidad_max_2 = plotted_data['Intensidad Max'].nlargest(2).iloc[1]
	
	x = (plotted_data['Ángulo'])
	average_y = (plotted_data['Intensidad Min'] + plotted_data['Intensidad Max'])/2
	
	plot, = figure.plot(x, average_y, '-.')
	plots.append(plot)

ax.legend(
	plots, ('({})'.format(label) for label in ['a', 'b', 'c', 'd']),
	shadow=True, fancybox=True
)

plt.savefig('Intensidades2.pdf', dpi=300)

# %%
fig1, ax1 = plt.subplots(figsize=(6,4))
ax1.set(xlabel='Ángulo [rad]', ylabel='Intensidad [mW]')
ax1.grid()

figure = ax1

plotted_data1 = mediciones[0]
sorted_data1 = plotted_data1.sort_values(by='Intensidad Min', ascending=False).iloc[1]
angulo_max1 = sorted_data1['Ángulo']
intensidad_max1 = sorted_data1['Intensidad Max']

x1 = (plotted_data1['Ángulo'])
average_y1 = (plotted_data1['Intensidad Min'] + plotted_data1['Intensidad Max'])/2

figure.scatter(x1, average_y1, label='Mediciones')
figure.plot(angulos, Malus_Ley(intensidad_max1, angulos-angulo_max1), 'k--', label= 'Ley de Malus')
ax1.legend()

MSE1 = (1/average_y1.size)*np.sum((average_y1-Malus_Ley(intensidad_max1, x1-angulo_max1))**2)
print('Polarizacion:', angulo_max1, np.degrees(angulo_max1))
print('Error cuadrático medio:', MSE1)

#plt.savefig('Intensidad1.pdf', dpi=300)
# Out:
# Polarizacion: 2.9670597283903604 170.0
# Error cuadrático medio: 0.0021066527620356664

# %%
intensidad_max1
# Out:
# np.float64(1.269)

# %%
fig2, ax2 = plt.subplots(figsize=(6,4))
ax2.set(xlabel='Ángulo [rad]', ylabel='Intensidad [mW]')
ax2.grid()

figure = ax2

plotted_data2 = mediciones[1]
sorted_data2 = plotted_data2.sort_values(by='Intensidad Min', ascending=False).iloc[0]
angulo_max2 = sorted_data2['Ángulo']
intensidad_max2 = sorted_data2['Intensidad Max']

x2 = (plotted_data2['Ángulo'])
average_y2 = (plotted_data2['Intensidad Min'] + plotted_data2['Intensidad Max'])/2

figure.scatter(x2, average_y2, label='Mediciones')
figure.plot(angulos, Malus_Ley(intensidad_max2, angulos-angulo_max2), 'k--', label= 'Ley de Malus 1')
#figure.plot(angulos, 2*intensidad_max2*Malus_Ley_MOD(angulos-angulo_max1), '--', label= 'Ley de Malus 2')
figure.plot(angulos, 2*intensidad_max2*Malus_Law_Retarder_1(angulos-angulo_max1), '--', label= 'Ley de Malus 2')
ax2.legend()

#plt.savefig('Intensidad2.pdf', dpi=300)
print(intensidad_max_2)
np.max(2*intensidad_max2*Malus_Ley_MOD(angulos-angulo_max1)- Malus_Ley(intensidad_max2, angulos-angulo_max2))
# Out:
# 0.627
# np.float64(1.2212453270876722e-15)

# %%
fig3, ax3 = plt.subplots(figsize=(6,4))
ax3.set(xlabel='Ángulo [rad]', ylabel='Intensidad [mW]')
ax3.grid()

figure = ax3

plotted_data3 = mediciones[2]
sorted_data3 = plotted_data3.sort_values(by='Intensidad Min', ascending=False).iloc[0]
angulo_max3 = sorted_data3['Ángulo']
intensidad_max3 = sorted_data3['Intensidad Max']

x3 = (plotted_data3['Ángulo'])
average_y3 = (plotted_data3['Intensidad Min'] + plotted_data3['Intensidad Max'])/2

figure.scatter(x3, average_y3, label='Mediciones')
figure.plot(angulos, Malus_Ley_MOD1(angulos-angulo_max3), 'k--', label= 'Ley de Malus')
ax3.legend()

#plt.savefig('Intensidad2.pdf', dpi=300)
